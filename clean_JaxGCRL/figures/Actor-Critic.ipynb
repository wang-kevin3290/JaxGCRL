# %%
import wandb
import pandas as pd
import matplotlib.pyplot as plt

# %%
api = wandb.Api()

# Project is specified by <entity/project-name>
runs = api.runs("wang-kevin3290-princeton-university/clean_JaxGCRL_test")

summary_list, config_list, name_list = [], [], []
for run in runs: 
    # .summary contains the output keys/values for metrics like accuracy.
    #  We call ._json_dict to omit large files 
    summary_list.append(run.summary._json_dict)

    # .config contains the hyperparameters.
    #  We remove special values that start with _.
    config_list.append(
        {k: v for k,v in run.config.items()
          if not k.startswith('_')})

    # .name is the human-readable name of the run.
    name_list.append(run.name)

runs_df = pd.DataFrame({
    "summary": summary_list,
    "config": config_list,
    "name": name_list
    })

# %%
runs_df.head()['summary'][0]
# Out:
# {'_runtime': 1092.8335332870483,
#  '_step': 9,
#  '_timestamp': 1729284398.2212093,
#  '_wandb': {'runtime': 1092},
#  'eval/avg_episode_length': 927.421875,
#  'eval/episode_dist': 1236.10888671875,
#  'eval/episode_distance_from_origin': 8270.16015625,
#  'eval/episode_reward': -231.15740966796875,
#  'eval/episode_success': 634.2109375,
#  'eval/episode_success_any': 0.96875,
#  'eval/episode_success_easy': 779.6171875,
#  'eval/epoch_eval_time': 2.125173568725586,
#  'eval/sps': 60230.374536776515,
#  'eval/walltime': 27.470006942749023,
#  'training/actor_loss': 1.895994544029236,
#  'training/alph_aloss': -5.87529666518094e-06,
#  'training/buffer_current_size': 9734,
#  'training/categorical_accuracy': 0.42519429326057434,
#  'training/critic_loss': 1.9470860958099363,
#  'training/envsteps': 9967616,
#  'training/log_alpha': -4.63176965713501,
#  'training/logits_neg': -12.381345748901367,
#  'training/logits_pos': -2.304131031036377,
#  'training/logsumexp': -0.4059561491012573,
#  'training/sample_entropy': -4.0007171630859375,
#  'training/sps': 8694.58664356389,
#  'training/walltime': 1044.5719707012177}

# %%
len(runs_df)
# Out:
# 3372

# %%
runs_df['name']
# Out:
# 0                           ant_1_256_10000000_1729283304
# 1                           ant_256_50000000_1729285442_1
# 2                  ant_big_maze_256_50000000_1729296307_8
# 3                  ant_big_maze_256_50000000_1729296405_9
# 4                          ant_256_50000000_1729310741_10
#                               ...
# 3367    humanoid_u_maze_512_critbx:1.0_actbx:1.0_batch...
# 3368    humanoid_u_maze_512_critbx:1.0_actbx:1.0_batch...
# 3369    humanoid_big_maze_512_critbx:1.0_actbx:1.0_bat...
# 3370    arm_binpick_hard_512_critbx:1.0_actbx:1.0_batc...
# 3371    arm_binpick_hard_512_critbx:1.0_actbx:1.0_batc...
# Name: name, Length: 3372, dtype: object

# %%
runs_df['config'][10]
# Out:
# {'cuda': True,
#  'seed': 13,
#  'gamma': 0.99,
#  'track': True,
#  'env_id': 'ant_hardest_maze',
#  'obs_dim': 0,
#  'actor_lr': 0.0003,
#  'alpha_lr': 0.0003,
#  'exp_name': 'train',
#  'num_envs': 1024,
#  'critic_lr': 0.0003,
#  'wandb_dir': '.',
#  'batch_size': 256,
#  'checkpoint': False,
#  'num_epochs': 200,
#  'wandb_mode': 'offline',
#  'wandb_group': None,
#  'goal_end_idx': 0,
#  'wandb_entity': 'wang-kevin3290-princeton-university',
#  'capture_video': True,
#  'num_eval_envs': 128,
#  'unroll_length': 62,
#  'episode_length': 1000,
#  'goal_start_idx': 0,
#  'max_replay_size': 10000,
#  'min_replay_size': 1000,
#  'total_env_steps': 200000000,
#  'wandb_project_name': 'clean_JaxGCRL_test',
#  'torch_deterministic': True,
#  'num_prefill_env_steps': 1024000,
#  'logsumexp_penalty_coeff': 0.1,
#  'num_prefill_actor_steps': 17,
#  'env_steps_per_actor_step': 63488,
#  'num_training_steps_per_epoch': 15}

# %%
runs_df
# Out:
#                                                 summary  \
# 0     {'_runtime': 1092.8335332870483, '_step': 9, '...
# 1     {'_runtime': 5263.2014718055725, '_step': 49, ...
# 2     {'_runtime': 14420.460032224655, '_step': 49, ...
# 3     {'_runtime': 14436.956994771956, '_step': 49, ...
# 4     {'_runtime': 11526.000489234924, '_step': 49, ...
# ...                                                 ...
# 3367                                                 {}
# 3368                                                 {}
# 3369                                                 {}
# 3370                                                 {}
# 3371                                                 {}
#
#                                                  config  \
# 0     {'cuda': True, 'seed': 1, 'gamma': 0.99, 'trac...
# 1     {'cuda': True, 'seed': 1, 'gamma': 0.99, 'trac...
# 2     {'cuda': True, 'seed': 8, 'gamma': 0.99, 'trac...
# 3     {'cuda': True, 'seed': 9, 'gamma': 0.99, 'trac...
# 4     {'cuda': True, 'seed': 10, 'gamma': 0.99, 'tra...
# ...                                                 ...
# 3367  {'mrn': 0, 'cuda': True, 'seed': 732, 'gamma':...
# 3368  {'mrn': 0, 'cuda': True, 'seed': 980, 'gamma':...
# 3369  {'mrn': 0, 'cuda': True, 'seed': 578, 'gamma':...
# 3370  {'mrn': 0, 'cuda': True, 'seed': 349, 'gamma':...
# 3371  {'mrn': 0, 'cuda': True, 'seed': 500, 'gamma':...
#
#                                                    name
# 0                         ant_1_256_10000000_1729283304
# 1                         ant_256_50000000_1729285442_1
# 2                ant_big_maze_256_50000000_1729296307_8
# 3                ant_big_maze_256_50000000_1729296405_9
# 4                        ant_256_50000000_1729310741_10
# ...                                                 ...
# 3367  humanoid_u_maze_512_critbx:1.0_actbx:1.0_batch...
# 3368  humanoid_u_maze_512_critbx:1.0_actbx:1.0_batch...
# 3369  humanoid_big_maze_512_critbx:1.0_actbx:1.0_bat...
# 3370  arm_binpick_hard_512_critbx:1.0_actbx:1.0_batc...
# 3371  arm_binpick_hard_512_critbx:1.0_actbx:1.0_batc...
#
# [3372 rows x 3 columns]

# %%
for run in runs:
    x = run
    break

# %%
x
# Out:
# <Run wang-kevin3290-princeton-university/clean_JaxGCRL_test/ul80z4j3 (finished)>
